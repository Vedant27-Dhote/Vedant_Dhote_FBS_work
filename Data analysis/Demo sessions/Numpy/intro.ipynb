# %% [markdown]
# #### Introduction
# 1. Extensible library
# 2. Faster than core python
# 3. Numneric - python
# 4. Mathematical operation like arithmatic, algebra, random sampling
# 5. multi - dimensional array, matrix, strings

# %% [markdown]
# ### Array Introduction
# 1. array([])
# 2. Homogenous
# 3. ordered
# 4. mutable, size-imutable
# 5. Dupliates elements are allowed
# 6. Numpy array is 50x faster than python list
