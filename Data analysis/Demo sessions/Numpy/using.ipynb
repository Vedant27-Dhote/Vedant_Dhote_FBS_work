# %%
import numpy as np

# %%
arr = np.array([10,20,30,40])
arr
# Out:
# array([10, 20, 30, 40])

# %%
arr2 = np.array([10,3.14,20])
arr2
# Out:
# array([10.  ,  3.14, 20.  ])

# %%
arr3 = np.array([10,3.14,"a"])
arr3
# Out:
# array(['10', '3.14', 'a'], dtype='<U32')
